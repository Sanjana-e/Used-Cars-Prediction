# %%
# Importing Libraries
import selenium
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup
from selenium import webdriver 
import requests
import re
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#connecting to the webdriver
driver = webdriver.Chrome(r"C:/webdriver/chromedriver.exe")

# %%
url = "https://www.cardekho.com/"
driver.get(url)
time.sleep(3)

# %%
#link for city
used_cars = driver.find_element_by_xpath("/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/ul/li[2]/a")

# %%
used_cars = used_cars.get_attribute('href')

# %%
driver.get(used_cars)
time.sleep(3)

# %%
cities = driver.find_elements_by_xpath("//ul[@class = 'listing gsc_col-md-9 gsc_col-lg-9']//li/a")

# %%
city = []
for i in cities:
    city.append(i.get_attribute('href'))

# %%
Car_brand = []
car_price = []
kms_driven = []
fuel = []
transmission = []
city_url = []
car_urls = []
for i in city:
    driver.get(i)
    time.sleep(3)
    
    for _ in range(150):
        time.sleep(1)
        driver.execute_script("window.scrollBy(0,1000)")
    current_url = driver.current_url    
    car = driver.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a")
    for i in car:
        car_urls.append(i.get_attribute('href'))
    #fetching
    for i in driver.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a"):
        Car_brand.append(i.text)
        city_url.append(current_url)
    #
    for i in driver.find_elements_by_xpath("//span[@class='amnt ']"):
        car_price.append(i.text)
    #
    for i in driver.find_elements_by_xpath("//div[@class='truncate dotlist']//span[1]"):
        kms_driven.append(i.text)
    #
    for i in driver.find_elements_by_xpath("//div[@class='truncate dotlist']//span[2]"):
        fuel.append(i.text)
    #
    for i in driver.find_elements_by_xpath("//div[@class='truncate dotlist']//span[3]"):
        transmission.append(i.text)

# %%
print(len(car_urls),len(Car_brand), len(city_url), len(car_price), len(kms_driven), len(fuel), len(transmission))
# Out:
# 5655 5655 5655 5655 5655 5655 5655

# %%
seats = []
engine_disp = []
milage = []
color = []
max_power = []
front_brake = []
rear_brake = []
cargo_vol = []
height = []
width = []
length = []
weight = []
insp_score = []
top_speed = []

# %%
for i in car_urls:
    driver.get(i)
    time.sleep(2)
    #clicking to view all specifications
    try:
        view_more = driver.find_element_by_xpath("//*[text() = 'View All Specifications' or text() = 'View More']")
        driver.execute_script("arguments[0].scrollIntoView();", view_more)
        driver.execute_script("arguments[0].click();", view_more)
        time.sleep(2)
    except NoSuchElementException:
        pass
    
    #fetching engine displacement
    try:
        eng = driver.find_element_by_xpath("//*[text()='Engine']/following-sibling::div") 
        engine_disp.append(eng.text.replace('CC',''))
    except NoSuchElementException:
        engine_disp.append('-')
    
    #fetch Mileage
    try:
        mil = driver.find_element_by_xpath("//*[text()='Mileage']/following-sibling::div")
        milage.append(mil.text)
    except NoSuchElementException:
        milage.append('-')
    #Fetching seating capacity
    try:
        sts = driver.find_element_by_xpath("//*[text()='Seating Capacity']/following-sibling::div")
        seats.append(sts.text)
    except NoSuchElementException:
        seats.append('-')
    #fetching colour
    try:
        clr = driver.find_element_by_xpath("//*[text()='Color']/following-sibling::div")
        color.append(clr.text)
    except NoSuchElementException:
        color.append('-')
    #fetching Maximum power
    try:
        pwr = driver.find_element_by_xpath("//*[text()='Max Power']/following-sibling::div")
        max_power.append(pwr.text.replace('bhp',''))
    except NoSuchElementException:
        max_power.append('-')
    #fetching Front brake type
    try:
        fbrk = driver.find_element_by_xpath("//*[text()='Front Brake Type']/following-sibling::div")
        front_brake.append(fbrk.text)
    except NoSuchElementException:
        front_brake.append('-')
    #fetching rear brake type
    try:
        rbrk = driver.find_element_by_xpath("//*[text()='Rear Brake Type']/following-sibling::div")
        rear_brake.append(rbrk.text)
    except NoSuchElementException:
        rear_brake.append('-')
    #fetching details of cargo volume
    try:
        vol = driver.find_element_by_xpath("//*[text()='Cargo Volumn']/following-sibling::div")
        cargo_vol.append(vol.text)
    except NoSuchElementException:
        cargo_vol.append('-')
    #fetching top speed
    try:
        speed = driver.find_element_by_xpath("//*[text()='Top Speed']/following-sibling::div")
        top_speed.append(speed.text)
    except NoSuchElementException:
        top_speed.append('-')
    #fetching height of the car
    try:
        hgt = driver.find_element_by_xpath("//*[text()='Height']/following-sibling::div")
        height.append(hgt.text.replace('mm',''))
    except NoSuchElementException:
        height.append('-')
    #fetching width
    try:
        wth = driver.find_element_by_xpath("//*[text()='Width']/following-sibling::div")
        width.append(wth.text.replace('mm',''))
    except NoSuchElementException:
        width.append('-')
    #fetching length of the car
    try:
        lth = driver.find_element_by_xpath("//*[text()='Length']/following-sibling::div")
        length.append(lth.text.replace('mm',''))
    except NoSuchElementException:
        length.append('-')
    #fetching gross weight
    try:
        weigh = driver.find_element_by_xpath("//*[text()='Gross Weight']/following-sibling::div")
        weight.append(weigh.text.replace('kg',''))
    except NoSuchElementException:
        weight.append('-')
    #fetching Inspection score
    try:
        insp = driver.find_element_by_xpath("//div[@class='inspectionRating right-side gsc_col-xs-5 text-right']/span")
        insp_score.append(insp.text)
    except NoSuchElementException:
        insp_score.append('-')

# %%
print(len(seats),len(engine_disp),len(milage),len(color),len(max_power),len(front_brake),len(rear_brake),len(cargo_vol),len(height),len(width),len(length),len(weight),len(insp_score),len(top_speed))
# Out:
# 5655 5655 5655 5655 5655 5655 5655 5655 5655 5655 5655 5655 5655 5655

# %%
#creating a dataframe
data = list(zip(Car_brand,fuel,kms_driven,engine_disp,transmission,milage,seats,color,max_power,front_brake,rear_brake,cargo_vol,height,width,length,weight,insp_score,top_speed,city_url,car_price))
df = pd.DataFrame(data, columns = ["Car_Name","Fuel_type","Running_in_kms","Endine_disp", "Gear_transmission","Milage_in_km/ltr","Seating_cap","color","Max_power","front_brake_type","rear_brake_type","cargo_volume","height","width","length","Weight","Insp_score","top_speed","City_url","Car_price"])
df
# Out:
#                      Car_Name Fuel_type Running_in_kms Endine_disp  \
# 0     2012 Maruti Swift Dzire    Diesel     80,134 kms           -
# 1        2019 Maruti S-Presso    Petrol     24,268 kms           -
# 2     2019 Maruti Swift Dzire    Petrol     11,935 kms           -
# 3            2016 Maruti Eeco    Petrol     45,384 kms           -
# 4       2018 Volkswagen Vento    Diesel     98,027 kms           -
# ...                       ...       ...            ...         ...
# 5650       2009 Toyota Innova    Diesel   1,74,855 kms           -
# 5651          2017 Honda Jazz    Petrol      9,000 kms           -
# 5652          2017 Honda City    Diesel     13,200 kms           -
# 5653          2017 Honda City    Diesel     10,000 kms           -
# 5654          2016 Honda BR-V    Diesel     19,800 kms           -
#
#      Gear_transmission Milage_in_km/ltr Seating_cap        color  \
# 0               manual                -           5         Grey
# 1               manual                -           5        White
# 2               manual                -           5  Oxford Blue
# 3               manual                -           5        White
# 4               manual                -           5       Silver
# ...                ...              ...         ...          ...
# 5650            manual                -           8       Silver
# 5651            manual                -           -            -
# 5652            manual                -           -            -
# 5653            manual                -           -            -
# 5654            manual                -           -            -
#
#                Max_power front_brake_type rear_brake_type cargo_volume  \
# 0             74@4000rpm  Ventilated Disc            Drum   320 liters
# 1          67.05@5500rpm  Ventilated Disc            Drum          270
# 2          81.80@6000rpm             Disc            Drum          378
# 3          72.42@6000rpm             Disc            Drum          540
# 4          108.6@4000rpm  Ventilated Disc            Drum          494
# ...                  ...              ...             ...          ...
# 5650  102@3,600 (PS@rpm)  Ventilated Disc            Drum            -
# 5651                   -                -               -            -
# 5652                   -                -               -            -
# 5653                   -                -               -            -
# 5654                   -                -               -            -
#
#       height   width  length  Weight Insp_score top_speed  \
# 0       1555    1695    3995    1505        8.5
# 1       1564    1520    3565    1170          -
# 2       1515    1735    3995  1315Kg          -
# 3       1825    1475    3675    1510        9.5
# 4       1467    1699    4390    1750          -  180 Kmph
# ...      ...     ...     ...     ...        ...       ...
# 5650  1,755   1,770   4,580     2220          -  151 kmph
# 5651       -       -       -       -          -         -
# 5652       -       -       -       -          -         -
# 5653       -       -       -       -          -         -
# 5654       -       -       -       -          -         -
#
#                                              City_url  Car_price
# 0     https://www.cardekho.com/used-cars+in+ahmedabad   3,13,000
# 1     https://www.cardekho.com/used-cars+in+ahmedabad   3,69,500
# 2     https://www.cardekho.com/used-cars+in+ahmedabad   6,80,000
# 3     https://www.cardekho.com/used-cars+in+ahmedabad   2,99,500
# 4     https://www.cardekho.com/used-cars+in+ahmedabad   7,86,500
# ...                                               ...        ...
# 5650       https://www.cardekho.com/used-cars+in+pune   4,85,000
# 5651       https://www.cardekho.com/used-cars+in+pune   7,00,000
# 5652       https://www.cardekho.com/used-cars+in+pune  14,15,000
# 5653       https://www.cardekho.com/used-cars+in+pune  14,15,000
# 5654       https://www.cardekho.com/used-cars+in+pune  11,50,000
#
# [5655 rows x 20 columns]

# %%
# Saving the scraped data into excel file
df.to_excel("Used_Cars.xlsx")

# %% [markdown]
# Finally we have scraped old cars data for important features from the mentioned website.

# %% [markdown]
# # Done:)
